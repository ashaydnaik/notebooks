# %% [markdown]
# Vectors are special objects that can be added together and multiplied by scalars to produce another object of the same kind. From an abstract mathematical viewpoint, any object that satisfies these two properties can be considered a vector.

# %% [markdown]
# Elements of $\mathbb{R}$ (tuples of $n$ real numbers) are vectors.
# The following is an example of a triplet of numbers:
#
# $$\mathbf{a} = \begin{bmatrix} 1 \\ 2 \\ 3 \end{bmatrix} \in \mathbb{R}^3$$

# %% [markdown]
# Adding 2 vectors $\mathbf{a},\mathbf{b} \in \mathbb{R}^n$ component-wise results in another vector: $\mathbf{a} + \mathbf{b} = c \in \mathbb{R}^n$

# %% [markdown]
# Multiplying $\mathbf{a} \in \mathbb{R}^n$ by $\lambda \in \mathbb{R}$ results in a scaled vector $\lambda\mathbf{a} \in \mathbb{R}^n$

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # 1. Systems of Linear Equations

# %% [markdown]
# A company produces products $N_1,..., N_n$ for which resources $R_1,..., R_m$ are required.
#
# To produce a unit of product $N_j$, $a_{ij}$ units of resource $R_i$ are needed, where $i = 1,...,m$ and $j = 1,...,n$.
#
# Thus, to produce a unit of product $N_1$, $a_{11}$ units of resource $R_1$ are needed.
#
# What is the optimal production plan? How many units $x_j$ of product $N_j$ should be produced if a total of $b_i$ units of resource $R_i$ are available and (ideally) no resources are left over?
#
# If we produce $x_1 ,..., x_n$ units of the corresponding products, we need a total of:
#
# $$ a_{i1}x_1 + \dots + a_{in}x_n $$
#
# many units of resource $R_i$. An optimal production plan $(x_1,..., x_n) \in \mathbb{R}^n$, therefore, has to satisfy the following system of equations:
#
# $$a_{11}x_1 + \dots + a_{1n}x_n = b_1 $$
# $$\vdots$$
# $$a_{m1}x_1 + \dots + a_{mn}x_n = b_m$$
# where $a_{ij} \in \mathbb{R}$ and $b_i \in \mathbb{R}$.
#
# This is the general form of a *system of linear equations* and $x_1,..., x_n$ are the *unknowns* of this system.
#
# Every $n$-tuple $(x_1,..., x_n) \in \mathbb{R}^n$ that satisfies this system of linear equations is a *solution*.
#
# In general, for a real-valued system of linear equations we obtain either no, exactly one, or infinitely many solutions.

# %% [markdown]
# For a systematic approach to solving systems of linear equations, collect the coefficients $a_{ij}$ into vectors and collect the vectors into matrices.
#
# $$x_1 \begin{bmatrix} a_{11} \\ \vdots \\ a_{m1} \end{bmatrix} +
# x_2 \begin{bmatrix} a_{12} \\ \vdots \\ a_{m2} \end{bmatrix} + \dots +
# x_n \begin{bmatrix} a_{1n} \\ \vdots \\ a_{mn} \end{bmatrix} =
# \begin{bmatrix} b_1 \\ \vdots \\ b_m \end{bmatrix} $$
#
# $$\iff \begin{bmatrix} a_{11} & \dots & a_{1n} \\ \vdots & \ddots & \vdots \\ a_{m1} & \dots & a_{mn} \end{bmatrix}
# \begin{bmatrix} x_1 \\ \vdots \\ x_n \end{bmatrix} =
# \begin{bmatrix} b_1 \\ \vdots \\ b_m \end{bmatrix} $$

# %% [markdown]
# # 2. Matrices

# %% [markdown]
# **Definition.** With $m, n \in \mathbb{N}$ a real-valued $(m, n)$ *matrix* $A$ is an $m \cdot n$-tuple of elements $a_{ij} , i = 1,...,m, j = 1,..., n$, which is ordered according to a rectangular scheme consisting of $m$ rows and $n$ columns:
#
# $$A = \begin{bmatrix} a_{11} & a_{12} & \dots & a_{1n} \\ a_{21} & a_{22} & \dots & a_{2n} \\ \vdots & \vdots & \ddots & \vdots \\ a_{m1} & a_{m2} & \dots & a_{mn} \end{bmatrix}, a_{ij} \in \mathbb{R}$$

# %% [markdown]
# ## Matrix Addition and Multiplication

# %% [markdown]
# Sum of two matrices $A \in \mathbb{R}^{m \times n}$, $B \in \mathbb{R}^{m \times n}$ is defined as the element-wise sum.
#
# $$ A + B = \begin{bmatrix} a_{11} + b_{11} & \dots & a_{1n} + b_{1n} \\ \vdots & \ddots & \vdots \\ a_{m1} + b_{m1} & \dots & a_{mn} + b_{mn} \end{bmatrix} \in \mathbb{R}^{m \times n} $$
#
# For matrices $A \in \mathbb{R}^{m \times n}$, $B \in \mathbb{R}^{n \times k}$, the elements $c_{ij}$ of the product $C = A \cdot B \in \mathbb{R}^{m \times k}$ are computed as:
#
# $$ c_{ij} = \sum_{l=1}^{n} a_{il}b_{lj}, i = 1,...,m, j = 1,...,k. $$

# %% [markdown]
# **Example**
#
# $A = \begin{bmatrix} 1 & 2 & 3 \\ 3 & 2 & 1 \end{bmatrix} \in \mathbb{R}^{2 \times 3}$,
# $B = \begin{bmatrix} 0 & 2 \\ 1 & -1 \\ 0 & 1 \end{bmatrix} \in \mathbb{R}^{3 \times 2}$
#
#
# $AB =
# \begin{bmatrix} 1 & 2 & 3 \\ 3 & 2 & 1 \end{bmatrix}
# \begin{bmatrix} 0 & 2 \\ 1 & -1 \\ 0 & 1 \end{bmatrix} =
# \begin{bmatrix} 2 & 3 \\ 2 & 5 \end{bmatrix} \in \mathbb{R}^{2 \times 2}$
#
# $BA =
# \begin{bmatrix} 0 & 2 \\ 1 & -1 \\ 0 & 1 \end{bmatrix}
# \begin{bmatrix} 1 & 2 & 3 \\ 3 & 2 & 1 \end{bmatrix} =
# \begin{bmatrix} 6 & 4 & 2 \\ -2 & 0 & 2 \\ 3 & 2 & 1 \end{bmatrix} \in \mathbb{R}^{3 \times 3}$
#
# Matrix multiplication is not commutative $AB \neq BA$.

# %% [markdown]
# **Identity Matrix.** The $n \times n$ matrix containing 1 on the diagnol and 0 everywhere else.
#
# $$I_n := \begin{bmatrix}
# 1 & 0 & \dots & 0 & \dots & 0 \\
# 0 & 1 & \dots & 0 & \dots & 0 \\
# \vdots & \vdots & \ddots & \vdots & \ddots & \vdots \\
# 0 & 0 & \dots & 1 & \dots & 0 \\
# \vdots & \vdots & \ddots & \vdots & \ddots & \vdots \\
# 0 & 0 & \dots & 0 & \dots & 1
# \end{bmatrix} \in \mathbb{R}^{n \times n}$$

# %% [markdown]
# **Associativity**
#
# $\forall A \in \mathbb{R}^{m \times n}, B \in \mathbb{R}^{n \times p}, C \in \mathbb{R}^{p \times q} : (AB)C = A(BC)$
#
# **Distributivity**
#
# $\forall A,B \in \mathbb{R}^{m \times n}, C,D \in \mathbb{R}^{n \times p} : (A + B)C = AC + BC, A(C + D) = AC + AD$
#
# **Multiplication with the identity matrix**
#
# $\forall A \in \mathbb{R}^{m \times n} : I_mA = AI_n = A$ <br>
# Note that $I_m \neq I_n$ for $m \neq n$
